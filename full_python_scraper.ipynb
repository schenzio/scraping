# %% [markdown]
# <a href="https://colab.research.google.com/github/schenzio/scraping/blob/main/full_python_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo scraper code: Get data on Nobel Prize winners
#
# * Source: [Nobel Prize Official Website](https://www.nobelprize.org/prizes/lists/all-nobel-prizes)

# %%
# !pip install requests
# !pip install requests_cache
# !pip install lxml
# !pip install pandas

# %% [markdown]
# ## 1. Import Libraries

# %%
import requests
import requests_cache
from lxml import html
import pandas as pd
from fractions import Fraction
import time
import re
import json

# %% [markdown]
# ## 2. Define functions and constants

# %%
BASE_URL = 'https://www.nobelprize.org'
OUTPUT_FILE = "winners.json"
requests_cache.install_cache('nobel_cache')

# %%
def get_root(url):
    r = requests.get(url)
    root = html.fromstring(r.text)
    if r.status_code == 200:
        return root
    else: 
        return None
       	print("HTTPS request failed with status code %s" % (r.status_code))


def process_winners(url):
    row = {}
    row['prize_id'] = abs(hash(url))
    row['source'] = url
    try:
        row['prize_year'] = int(url.split('/')[-4])
        row['prize_category'] = url.split('/')[-5]
    except ValueError:
        row['prize_year'] = int(url.split('/')[-2])
        row['prize_category'] = url.split('/')[-4]
        
    response_w = requests.get(url)
    root_w = html.fromstring(response_w.text)
    row['name'] = root_w.xpath('//header/h1')[0].text_content().strip()
    row['image_url'] = root_w.xpath('//div[@class="image"]/picture/source')[-1].get('data-srcset')
    row['prize_share'] = float(Fraction(root_w.xpath('//text()[contains(., "Prize share:")]')[0].split(':')[-1].strip()))
    
    
    #dead or alive?
    try:
        row['death_date'] = root_w.xpath('//text()[contains(., "Died:")]')[0].strip().split(':')[1].split(',')[0].split(' ')[-1].strip()
        row['alive_status'] = 'dead'
    except IndexError:
        row['death_date'] = ''
        row['alive_status'] = 'alive'
    
    
    #Check winner type
    
    try:
        row['birth_year'] = root_w.xpath('//text()[contains(., "Born:")]')[0].strip().split(':')[1].split(',')[0].split(' ')[-1].strip()
        row['entity'] = 'person'
    except IndexError:
        row['birth_year'] = ''
        row['entity'] = 'organization'
    

    #Check if prize accepted
    pattern = re.compile('declined the Nobel')
    match = re.search(pattern,response_w.text)
    if match:
        row['acceptance'] = 'declined'
    else:
        row['acceptance'] = 'accepted'
    
    #time.sleep(5)
    #print(row['alive_status']+"-"+row['name']+ '-'+str(row['death_date']))
    return row


def export_json(dictlist,output_file):
    with open(output_file, 'w') as f:
        json.dump(dictlist,f)
    print('Exported as .json to %s' % (output_file))


requests_cache.install_cache('nobel_cache')

# %% [markdown]
# ## 3. Scrape and save

# %%
start_url = BASE_URL+'/nobel_prizes/lists/all/'
root = get_root(start_url)
winner_urls = [url.get('href') for url in root.xpath("//div[@class='by_year']/p/a")]

all_winners = len(winner_urls) # --> should be 962, see here: https://www.nobelprize.org/prizes/
data = []
processed = 0

for url in winner_urls:
    try:
        row = process_winners(url)
        data.append(row)
        processed +=1
        print("Processed : %d/%d > %.2f%%" % (processed, all_winners, round((processed/all_winners)*100,2)))
    except Exception as e:
        print(url)
        print(e)

export_json(data,OUTPUT_FILE)
# Out:
# Processed : 1/963 > 0.10%
# Processed : 2/963 > 0.21%
# Processed : 3/963 > 0.31%
# Processed : 4/963 > 0.42%
# Processed : 5/963 > 0.52%
# Processed : 6/963 > 0.62%
# Processed : 7/963 > 0.73%
# Processed : 8/963 > 0.83%
# Processed : 9/963 > 0.93%
# Processed : 10/963 > 1.04%
# Processed : 11/963 > 1.14%
# Processed : 12/963 > 1.25%
# Processed : 13/963 > 1.35%
# Processed : 14/963 > 1.45%
# Processed : 15/963 > 1.56%
# Processed : 16/963 > 1.66%
# Processed : 17/963 > 1.77%
# Processed : 18/963 > 1.87%
# Processed : 19/963 > 1.97%
# Processed : 20/963 > 2.08%
# Processed : 21/963 > 2.18%
# Processed : 22/963 > 2.28%
# https://www.nobelprize.org/prizes/peace/2019/summary/
# invalid literal for int() with base 10: 'summary'
# Processed : 23/963 > 2.39%
# Processed : 24/963 > 2.49%
# Processed : 25/963 > 2.60%
# Processed : 26/963 > 2.70%
# Processed : 27/963 > 2.80%
# Processed : 28/963 > 2.91%
# Processed : 29/963 > 3.01%
# Processed : 30/963 > 3.12%
# Processed : 31/963 > 3.22%
# Processed : 32/963 > 3.32%
# Processed : 33/963 > 3.43%
# Processed : 34/963 > 3.53%
# Processed : 35/963 > 3.63%
# Processed : 36/963 > 3.74%
# Processed : 37/963 > 3.84%
# Processed : 38/963 > 3.95%
# Processed : 39/963 > 4.05%
# Processed : 40/963 > 4.15%
# Processed : 41/963 > 4.26%
# Processed : 42/963 > 4.36%
# Processed : 43/963 > 4.47%
# Processed : 44/963 > 4.57%
# Processed : 45/963 > 4.67%
# Processed : 46/963 > 4.78%
# Processed : 47/963 > 4.88%
# Processed : 48/963 > 4.98%
# Processed : 49/963 > 5.09%
# Processed : 50/963 > 5.19%
# Processed : 51/963 > 5.30%
# Processed : 52/963 > 5.40%
# Processed : 53/963 > 5.50%
# Processed : 54/963 > 5.61%
# Processed : 55/963 > 5.71%
# Processed : 56/963 > 5.82%
# Processed : 57/963 > 5.92%
# Processed : 58/963 > 6.02%
# Processed : 59/963 > 6.13%
# Processed : 60/963 > 6.23%
# Processed : 61/963 > 6.33%
# Processed : 62/963 > 6.44%
# Processed : 63/963 > 6.54%
# Processed : 64/963 > 6.65%
# Processed : 65/963 > 6.75%
# Processed : 66/963 > 6.85%
# Processed : 67/963 > 6.96%
# Processed : 68/963 > 7.06%
# Processed : 69/963 > 7.17%
# Processed : 70/963 > 7.27%
# Processed : 71/963 > 7.37%
# Processed : 72/963 > 7.48%
# Processed : 73/963 > 7.58%
# Processed : 74/963 > 7.68%
# Processed : 75/963 > 7.79%
# Processed : 76/963 > 7.89%
# Processed : 77/963 > 8.00%
# Processed : 78/963 > 8.10%
# Processed : 79/963 > 8.20%
# Processed : 80/963 > 8.31%
# Processed : 81/963 > 8.41%
# Processed : 82/963 > 8.52%
# Processed : 83/963 > 8.62%
# Processed : 84/963 > 8.72%
# Processed : 85/963 > 8.83%
# Processed : 86/963 > 8.93%
# Processed : 87/963 > 9.03%
# Processed : 88/963 > 9.14%
# Processed : 89/963 > 9.24%
# Processed : 90/963 > 9.35%
# Processed : 91/963 > 9.45%
# Processed : 92/963 > 9.55%
# Processed : 93/963 > 9.66%
# Processed : 94/963 > 9.76%
# Processed : 95/963 > 9.87%
# Processed : 96/963 > 9.97%
# Processed : 97/963 > 10.07%
# Processed : 98/963 > 10.18%
# Processed : 99/963 > 10.28%
# Processed : 100/963 > 10.38%
# Processed : 101/963 > 10.49%
# Processed : 102/963 > 10.59%
# Processed : 103/963 > 10.70%
# Processed : 104/963 > 10.80%
# Processed : 105/963 > 10.90%
# Processed : 106/963 > 11.01%
# Processed : 107/963 > 11.11%
# Processed : 108/963 > 11.21%
# Processed : 109/963 > 11.32%
# Processed : 110/963 > 11.42%
# Processed : 111/963 > 11.53%
# Processed : 112/963 > 11.63%
# Processed : 113/963 > 11.73%
# Processed : 114/963 > 11.84%
# Processed : 115/963 > 11.94%
# Processed : 116/963 > 12.05%
# Processed : 117/963 > 12.15%
# Processed : 118/963 > 12.25%
# Processed : 119/963 > 12.36%
# Processed : 120/963 > 12.46%
# Processed : 121/963 > 12.56%
# Processed : 122/963 > 12.67%
# Processed : 123/963 > 12.77%
# Processed : 124/963 > 12.88%
# Processed : 125/963 > 12.98%
# Processed : 126/963 > 13.08%
# Processed : 127/963 > 13.19%
# Processed : 128/963 > 13.29%
# Processed : 129/963 > 13.40%
# Processed : 130/963 > 13.50%
# Processed : 131/963 > 13.60%
# Processed : 132/963 > 13.71%
# Processed : 133/963 > 13.81%
# Processed : 134/963 > 13.91%
# Processed : 135/963 > 14.02%
# Processed : 136/963 > 14.12%
# Processed : 137/963 > 14.23%
# Processed : 138/963 > 14.33%
# Processed : 139/963 > 14.43%
# Processed : 140/963 > 14.54%
# Processed : 141/963 > 14.64%
# Processed : 142/963 > 14.75%
# Processed : 143/963 > 14.85%
# Processed : 144/963 > 14.95%
# Processed : 145/963 > 15.06%
# Processed : 146/963 > 15.16%
# Processed : 147/963 > 15.26%
# Processed : 148/963 > 15.37%
# Processed : 149/963 > 15.47%
# Processed : 150/963 > 15.58%
# Processed : 151/963 > 15.68%
# Processed : 152/963 > 15.78%
# Processed : 153/963 > 15.89%
# Processed : 154/963 > 15.99%
# Processed : 155/963 > 16.10%
# Processed : 156/963 > 16.20%
# Processed : 157/963 > 16.30%
# Processed : 158/963 > 16.41%
# Processed : 159/963 > 16.51%
# Processed : 160/963 > 16.61%
# Processed : 161/963 > 16.72%
# Processed : 162/963 > 16.82%
# Processed : 163/963 > 16.93%
# Processed : 164/963 > 17.03%
# Processed : 165/963 > 17.13%
# Processed : 166/963 > 17.24%
# Processed : 167/963 > 17.34%
# Processed : 168/963 > 17.45%
# Processed : 169/963 > 17.55%
# Processed : 170/963 > 17.65%
# Processed : 171/963 > 17.76%
# Processed : 172/963 > 17.86%
# Processed : 173/963 > 17.96%
# Processed : 174/963 > 18.07%
# Processed : 175/963 > 18.17%
# Processed : 176/963 > 18.28%
# Processed : 177/963 > 18.38%
# Processed : 178/963 > 18.48%
# Processed : 179/963 > 18.59%
# Processed : 180/963 > 18.69%
# Processed : 181/963 > 18.80%
# Processed : 182/963 > 18.90%
# Processed : 183/963 > 19.00%
# Processed : 184/963 > 19.11%
# Processed : 185/963 > 19.21%
# Processed : 186/963 > 19.31%
# Processed : 187/963 > 19.42%
# Processed : 188/963 > 19.52%
# Processed : 189/963 > 19.63%
# Processed : 190/963 > 19.73%
# Processed : 191/963 > 19.83%
# Processed : 192/963 > 19.94%
# Processed : 193/963 > 20.04%
# Processed : 194/963 > 20.15%
# Processed : 195/963 > 20.25%
# Processed : 196/963 > 20.35%
# Processed : 197/963 > 20.46%
# Processed : 198/963 > 20.56%
# Processed : 199/963 > 20.66%
# Processed : 200/963 > 20.77%
# Processed : 201/963 > 20.87%
# Processed : 202/963 > 20.98%
# Processed : 203/963 > 21.08%
# Processed : 204/963 > 21.18%
# Processed : 205/963 > 21.29%
# Processed : 206/963 > 21.39%
# Processed : 207/963 > 21.50%
# Processed : 208/963 > 21.60%
# Processed : 209/963 > 21.70%
# Processed : 210/963 > 21.81%
# Processed : 211/963 > 21.91%
# Processed : 212/963 > 22.01%
# Processed : 213/963 > 22.12%
# Processed : 214/963 > 22.22%
# Processed : 215/963 > 22.33%
# Processed : 216/963 > 22.43%
# Processed : 217/963 > 22.53%
# Processed : 218/963 > 22.64%
# Processed : 219/963 > 22.74%
# Processed : 220/963 > 22.85%
# Processed : 221/963 > 22.95%
# Processed : 222/963 > 23.05%
# Processed : 223/963 > 23.16%
# Processed : 224/963 > 23.26%
# Processed : 225/963 > 23.36%
# Processed : 226/963 > 23.47%
# Processed : 227/963 > 23.57%
# Processed : 228/963 > 23.68%
# Processed : 229/963 > 23.78%
# Processed : 230/963 > 23.88%
# Processed : 231/963 > 23.99%
# Processed : 232/963 > 24.09%
# Processed : 233/963 > 24.20%
# Processed : 234/963 > 24.30%
# Processed : 235/963 > 24.40%
# Processed : 236/963 > 24.51%
# Processed : 237/963 > 24.61%
# Processed : 238/963 > 24.71%
# Processed : 239/963 > 24.82%
# Processed : 240/963 > 24.92%
# Processed : 241/963 > 25.03%
# Processed : 242/963 > 25.13%
# Processed : 243/963 > 25.23%
# Processed : 244/963 > 25.34%
# Processed : 245/963 > 25.44%
# Processed : 246/963 > 25.55%
# Processed : 247/963 > 25.65%
# Processed : 248/963 > 25.75%
# Processed : 249/963 > 25.86%
# Processed : 250/963 > 25.96%
# Processed : 251/963 > 26.06%
# Processed : 252/963 > 26.17%
# Processed : 253/963 > 26.27%
# Processed : 254/963 > 26.38%
# Processed : 255/963 > 26.48%
# Processed : 256/963 > 26.58%
# Processed : 257/963 > 26.69%
# Processed : 258/963 > 26.79%
# Processed : 259/963 > 26.90%
# Processed : 260/963 > 27.00%
# Processed : 261/963 > 27.10%
# Processed : 262/963 > 27.21%
# Processed : 263/963 > 27.31%
# Processed : 264/963 > 27.41%
# Processed : 265/963 > 27.52%
# Processed : 266/963 > 27.62%
# Processed : 267/963 > 27.73%
# Processed : 268/963 > 27.83%
# Processed : 269/963 > 27.93%
# Processed : 270/963 > 28.04%
# Processed : 271/963 > 28.14%
# Processed : 272/963 > 28.25%
# Processed : 273/963 > 28.35%
# Processed : 274/963 > 28.45%
# Processed : 275/963 > 28.56%
# Processed : 276/963 > 28.66%
# Processed : 277/963 > 28.76%
# Processed : 278/963 > 28.87%
# Processed : 279/963 > 28.97%
# Processed : 280/963 > 29.08%
# Processed : 281/963 > 29.18%
# Processed : 282/963 > 29.28%
# Processed : 283/963 > 29.39%
# Processed : 284/963 > 29.49%
# Processed : 285/963 > 29.60%
# Processed : 286/963 > 29.70%
# Processed : 287/963 > 29.80%
# Processed : 288/963 > 29.91%
# Processed : 289/963 > 30.01%
# Processed : 290/963 > 30.11%
# Processed : 291/963 > 30.22%
# Processed : 292/963 > 30.32%
# Processed : 293/963 > 30.43%
# Processed : 294/963 > 30.53%
# Processed : 295/963 > 30.63%
# Processed : 296/963 > 30.74%
# Processed : 297/963 > 30.84%
# Processed : 298/963 > 30.94%
# Processed : 299/963 > 31.05%
# Processed : 300/963 > 31.15%
# Processed : 301/963 > 31.26%
# Processed : 302/963 > 31.36%
# Processed : 303/963 > 31.46%
# Processed : 304/963 > 31.57%
# Processed : 305/963 > 31.67%
# Processed : 306/963 > 31.78%
# Processed : 307/963 > 31.88%
# Processed : 308/963 > 31.98%
# Processed : 309/963 > 32.09%
# Processed : 310/963 > 32.19%
# Processed : 311/963 > 32.29%
# Processed : 312/963 > 32.40%
# Processed : 313/963 > 32.50%
# Processed : 314/963 > 32.61%
# Processed : 315/963 > 32.71%
# Processed : 316/963 > 32.81%
# Processed : 317/963 > 32.92%
# Processed : 318/963 > 33.02%
# Processed : 319/963 > 33.13%
# Processed : 320/963 > 33.23%
# Processed : 321/963 > 33.33%
# Processed : 322/963 > 33.44%
# Processed : 323/963 > 33.54%
# Processed : 324/963 > 33.64%
# Processed : 325/963 > 33.75%
# Processed : 326/963 > 33.85%
# Processed : 327/963 > 33.96%
# Processed : 328/963 > 34.06%
# Processed : 329/963 > 34.16%
# Processed : 330/963 > 34.27%
# Processed : 331/963 > 34.37%
# Processed : 332/963 > 34.48%
# Processed : 333/963 > 34.58%
# Processed : 334/963 > 34.68%
# Processed : 335/963 > 34.79%
# Processed : 336/963 > 34.89%
# Processed : 337/963 > 34.99%
# Processed : 338/963 > 35.10%
# Processed : 339/963 > 35.20%
# Processed : 340/963 > 35.31%
# Processed : 341/963 > 35.41%
# Processed : 342/963 > 35.51%
# Processed : 343/963 > 35.62%
# Processed : 344/963 > 35.72%
# Processed : 345/963 > 35.83%
# Processed : 346/963 > 35.93%
# Processed : 347/963 > 36.03%
# Processed : 348/963 > 36.14%
# Processed : 349/963 > 36.24%
# Processed : 350/963 > 36.34%
# Processed : 351/963 > 36.45%
# Processed : 352/963 > 36.55%
# Processed : 353/963 > 36.66%
# Processed : 354/963 > 36.76%
# Processed : 355/963 > 36.86%
# Processed : 356/963 > 36.97%
# Processed : 357/963 > 37.07%
# Processed : 358/963 > 37.18%
# Processed : 359/963 > 37.28%
# Processed : 360/963 > 37.38%
# Processed : 361/963 > 37.49%
# Processed : 362/963 > 37.59%
# Processed : 363/963 > 37.69%
# Processed : 364/963 > 37.80%
# Processed : 365/963 > 37.90%
# Processed : 366/963 > 38.01%
# Processed : 367/963 > 38.11%
# Processed : 368/963 > 38.21%
# Processed : 369/963 > 38.32%
# Processed : 370/963 > 38.42%
# Processed : 371/963 > 38.53%
# Processed : 372/963 > 38.63%
# Processed : 373/963 > 38.73%
# Processed : 374/963 > 38.84%
# Processed : 375/963 > 38.94%
# Processed : 376/963 > 39.04%
# Processed : 377/963 > 39.15%
# Processed : 378/963 > 39.25%
# Processed : 379/963 > 39.36%
# Processed : 380/963 > 39.46%
# Processed : 381/963 > 39.56%
# Processed : 382/963 > 39.67%
# Processed : 383/963 > 39.77%
# Processed : 384/963 > 39.88%
# Processed : 385/963 > 39.98%
# Processed : 386/963 > 40.08%
# Processed : 387/963 > 40.19%
# Processed : 388/963 > 40.29%
# Processed : 389/963 > 40.39%
# Processed : 390/963 > 40.50%
# Processed : 391/963 > 40.60%
# Processed : 392/963 > 40.71%
# Processed : 393/963 > 40.81%
# Processed : 394/963 > 40.91%
# Processed : 395/963 > 41.02%
# Processed : 396/963 > 41.12%
# Processed : 397/963 > 41.23%
# Processed : 398/963 > 41.33%
# Processed : 399/963 > 41.43%
# Processed : 400/963 > 41.54%
# Processed : 401/963 > 41.64%
# Processed : 402/963 > 41.74%
# Processed : 403/963 > 41.85%
# Processed : 404/963 > 41.95%
# Processed : 405/963 > 42.06%
# Processed : 406/963 > 42.16%
# Processed : 407/963 > 42.26%
# Processed : 408/963 > 42.37%
# Processed : 409/963 > 42.47%
# Processed : 410/963 > 42.58%
# Processed : 411/963 > 42.68%
# Processed : 412/963 > 42.78%
# Processed : 413/963 > 42.89%
# Processed : 414/963 > 42.99%
# Processed : 415/963 > 43.09%
# Processed : 416/963 > 43.20%
# Processed : 417/963 > 43.30%
# Processed : 418/963 > 43.41%
# Processed : 419/963 > 43.51%
# Processed : 420/963 > 43.61%
# Processed : 421/963 > 43.72%
# Processed : 422/963 > 43.82%
# Processed : 423/963 > 43.93%
# Processed : 424/963 > 44.03%
# Processed : 425/963 > 44.13%
# Processed : 426/963 > 44.24%
# Processed : 427/963 > 44.34%
# Processed : 428/963 > 44.44%
# Processed : 429/963 > 44.55%
# Processed : 430/963 > 44.65%
# Processed : 431/963 > 44.76%
# Processed : 432/963 > 44.86%
# Processed : 433/963 > 44.96%
# Processed : 434/963 > 45.07%
# Processed : 435/963 > 45.17%
# Processed : 436/963 > 45.28%
# Processed : 437/963 > 45.38%
# Processed : 438/963 > 45.48%
# Processed : 439/963 > 45.59%
# Processed : 440/963 > 45.69%
# Processed : 441/963 > 45.79%
# Processed : 442/963 > 45.90%
# Processed : 443/963 > 46.00%
# Processed : 444/963 > 46.11%
# Processed : 445/963 > 46.21%
# Processed : 446/963 > 46.31%
# Processed : 447/963 > 46.42%
# Processed : 448/963 > 46.52%
# Processed : 449/963 > 46.63%
# Processed : 450/963 > 46.73%
# Processed : 451/963 > 46.83%
# Processed : 452/963 > 46.94%
# Processed : 453/963 > 47.04%
# Processed : 454/963 > 47.14%
# Processed : 455/963 > 47.25%
# Processed : 456/963 > 47.35%
# Processed : 457/963 > 47.46%
# Processed : 458/963 > 47.56%
# Processed : 459/963 > 47.66%
# Processed : 460/963 > 47.77%
# Processed : 461/963 > 47.87%
# Processed : 462/963 > 47.98%
# Processed : 463/963 > 48.08%
# Processed : 464/963 > 48.18%
# Processed : 465/963 > 48.29%
# Processed : 466/963 > 48.39%
# Processed : 467/963 > 48.49%
# Processed : 468/963 > 48.60%
# Processed : 469/963 > 48.70%
# Processed : 470/963 > 48.81%
# Processed : 471/963 > 48.91%
# Processed : 472/963 > 49.01%
# Processed : 473/963 > 49.12%
# Processed : 474/963 > 49.22%
# Processed : 475/963 > 49.33%
# Processed : 476/963 > 49.43%
# Processed : 477/963 > 49.53%
# Processed : 478/963 > 49.64%
# Processed : 479/963 > 49.74%
# Processed : 480/963 > 49.84%
# Processed : 481/963 > 49.95%
# Processed : 482/963 > 50.05%
# Processed : 483/963 > 50.16%
# Processed : 484/963 > 50.26%
# Processed : 485/963 > 50.36%
# Processed : 486/963 > 50.47%
# Processed : 487/963 > 50.57%
# Processed : 488/963 > 50.67%
# Processed : 489/963 > 50.78%
# Processed : 490/963 > 50.88%
# Processed : 491/963 > 50.99%
# Processed : 492/963 > 51.09%
# Processed : 493/963 > 51.19%
# Processed : 494/963 > 51.30%
# Processed : 495/963 > 51.40%
# Processed : 496/963 > 51.51%
# Processed : 497/963 > 51.61%
# Processed : 498/963 > 51.71%
# Processed : 499/963 > 51.82%
# Processed : 500/963 > 51.92%
# Processed : 501/963 > 52.02%
# Processed : 502/963 > 52.13%
# Processed : 503/963 > 52.23%
# Processed : 504/963 > 52.34%
# Processed : 505/963 > 52.44%
# Processed : 506/963 > 52.54%
# Processed : 507/963 > 52.65%
# Processed : 508/963 > 52.75%
# Processed : 509/963 > 52.86%
# Processed : 510/963 > 52.96%
# Processed : 511/963 > 53.06%
# Processed : 512/963 > 53.17%
# Processed : 513/963 > 53.27%
# Processed : 514/963 > 53.37%
# Processed : 515/963 > 53.48%
# Processed : 516/963 > 53.58%
# Processed : 517/963 > 53.69%
# Processed : 518/963 > 53.79%
# Processed : 519/963 > 53.89%
# Processed : 520/963 > 54.00%
# Processed : 521/963 > 54.10%
# Processed : 522/963 > 54.21%
# Processed : 523/963 > 54.31%
# Processed : 524/963 > 54.41%
# Processed : 525/963 > 54.52%
# Processed : 526/963 > 54.62%
# Processed : 527/963 > 54.72%
# Processed : 528/963 > 54.83%
# Processed : 529/963 > 54.93%
# Processed : 530/963 > 55.04%
# Processed : 531/963 > 55.14%
# Processed : 532/963 > 55.24%
# Processed : 533/963 > 55.35%
# Processed : 534/963 > 55.45%
# Processed : 535/963 > 55.56%
# Processed : 536/963 > 55.66%
# Processed : 537/963 > 55.76%
# Processed : 538/963 > 55.87%
# Processed : 539/963 > 55.97%
# Processed : 540/963 > 56.07%
# Processed : 541/963 > 56.18%
# Processed : 542/963 > 56.28%
# Processed : 543/963 > 56.39%
# Processed : 544/963 > 56.49%
# Processed : 545/963 > 56.59%
# Processed : 546/963 > 56.70%
# Processed : 547/963 > 56.80%
# Processed : 548/963 > 56.91%
# Processed : 549/963 > 57.01%
# Processed : 550/963 > 57.11%
# Processed : 551/963 > 57.22%
# Processed : 552/963 > 57.32%
# Processed : 553/963 > 57.42%
# Processed : 554/963 > 57.53%
# Processed : 555/963 > 57.63%
# Processed : 556/963 > 57.74%
# Processed : 557/963 > 57.84%
# Processed : 558/963 > 57.94%
# Processed : 559/963 > 58.05%
# Processed : 560/963 > 58.15%
# Processed : 561/963 > 58.26%
# Processed : 562/963 > 58.36%
# Processed : 563/963 > 58.46%
# Processed : 564/963 > 58.57%
# Processed : 565/963 > 58.67%
# Processed : 566/963 > 58.77%
# Processed : 567/963 > 58.88%
# Processed : 568/963 > 58.98%
# Processed : 569/963 > 59.09%
# Processed : 570/963 > 59.19%
# Processed : 571/963 > 59.29%
# Processed : 572/963 > 59.40%
# Processed : 573/963 > 59.50%
# Processed : 574/963 > 59.61%
# Processed : 575/963 > 59.71%
# Processed : 576/963 > 59.81%
# Processed : 577/963 > 59.92%
# Processed : 578/963 > 60.02%
# Processed : 579/963 > 60.12%
# Processed : 580/963 > 60.23%
# Processed : 581/963 > 60.33%
# Processed : 582/963 > 60.44%
# Processed : 583/963 > 60.54%
# Processed : 584/963 > 60.64%
# Processed : 585/963 > 60.75%
# Processed : 586/963 > 60.85%
# Processed : 587/963 > 60.96%
# Processed : 588/963 > 61.06%
# Processed : 589/963 > 61.16%
# Processed : 590/963 > 61.27%
# Processed : 591/963 > 61.37%
# Processed : 592/963 > 61.47%
# Processed : 593/963 > 61.58%
# Processed : 594/963 > 61.68%
# Processed : 595/963 > 61.79%
# Processed : 596/963 > 61.89%
# Processed : 597/963 > 61.99%
# Processed : 598/963 > 62.10%
# Processed : 599/963 > 62.20%
# Processed : 600/963 > 62.31%
# Processed : 601/963 > 62.41%
# Processed : 602/963 > 62.51%
# Processed : 603/963 > 62.62%
# Processed : 604/963 > 62.72%
# Processed : 605/963 > 62.82%
# Processed : 606/963 > 62.93%
# Processed : 607/963 > 63.03%
# Processed : 608/963 > 63.14%
# Processed : 609/963 > 63.24%
# Processed : 610/963 > 63.34%
# Processed : 611/963 > 63.45%
# Processed : 612/963 > 63.55%
# Processed : 613/963 > 63.66%
# Processed : 614/963 > 63.76%
# Processed : 615/963 > 63.86%
# Processed : 616/963 > 63.97%
# Processed : 617/963 > 64.07%
# Processed : 618/963 > 64.17%
# Processed : 619/963 > 64.28%
# Processed : 620/963 > 64.38%
# Processed : 621/963 > 64.49%
# Processed : 622/963 > 64.59%
# Processed : 623/963 > 64.69%
# Processed : 624/963 > 64.80%
# Processed : 625/963 > 64.90%
# Processed : 626/963 > 65.01%
# Processed : 627/963 > 65.11%
# Processed : 628/963 > 65.21%
# Processed : 629/963 > 65.32%
# Processed : 630/963 > 65.42%
# Processed : 631/963 > 65.52%
# Processed : 632/963 > 65.63%
# Processed : 633/963 > 65.73%
# Processed : 634/963 > 65.84%
# Processed : 635/963 > 65.94%
# Processed : 636/963 > 66.04%
# Processed : 637/963 > 66.15%
# Processed : 638/963 > 66.25%
# Processed : 639/963 > 66.36%
# Processed : 640/963 > 66.46%
# Processed : 641/963 > 66.56%
# Processed : 642/963 > 66.67%
# Processed : 643/963 > 66.77%
# Processed : 644/963 > 66.87%
# Processed : 645/963 > 66.98%
# Processed : 646/963 > 67.08%
# Processed : 647/963 > 67.19%
# Processed : 648/963 > 67.29%
# Processed : 649/963 > 67.39%
# Processed : 650/963 > 67.50%
# Processed : 651/963 > 67.60%
# Processed : 652/963 > 67.71%
# Processed : 653/963 > 67.81%
# Processed : 654/963 > 67.91%
# Processed : 655/963 > 68.02%
# Processed : 656/963 > 68.12%
# Processed : 657/963 > 68.22%
# Processed : 658/963 > 68.33%
# Processed : 659/963 > 68.43%
# Processed : 660/963 > 68.54%
# Processed : 661/963 > 68.64%
# Processed : 662/963 > 68.74%
# Processed : 663/963 > 68.85%
# Processed : 664/963 > 68.95%
# Processed : 665/963 > 69.06%
# Processed : 666/963 > 69.16%
# Processed : 667/963 > 69.26%
# Processed : 668/963 > 69.37%
# Processed : 669/963 > 69.47%
# Processed : 670/963 > 69.57%
# Processed : 671/963 > 69.68%
# Processed : 672/963 > 69.78%
# Processed : 673/963 > 69.89%
# Processed : 674/963 > 69.99%
# Processed : 675/963 > 70.09%
# Processed : 676/963 > 70.20%
# Processed : 677/963 > 70.30%
# Processed : 678/963 > 70.40%
# Processed : 679/963 > 70.51%
# Processed : 680/963 > 70.61%
# Processed : 681/963 > 70.72%
# Processed : 682/963 > 70.82%
# Processed : 683/963 > 70.92%
# Processed : 684/963 > 71.03%
# Processed : 685/963 > 71.13%
# Processed : 686/963 > 71.24%
# Processed : 687/963 > 71.34%
# Processed : 688/963 > 71.44%
# Processed : 689/963 > 71.55%
# Processed : 690/963 > 71.65%
# Processed : 691/963 > 71.75%
# Processed : 692/963 > 71.86%
# Processed : 693/963 > 71.96%
# Processed : 694/963 > 72.07%
# Processed : 695/963 > 72.17%
# Processed : 696/963 > 72.27%
# Processed : 697/963 > 72.38%
# Processed : 698/963 > 72.48%
# Processed : 699/963 > 72.59%
# Processed : 700/963 > 72.69%
# Processed : 701/963 > 72.79%
# Processed : 702/963 > 72.90%
# Processed : 703/963 > 73.00%
# Processed : 704/963 > 73.10%
# Processed : 705/963 > 73.21%
# Processed : 706/963 > 73.31%
# Processed : 707/963 > 73.42%
# Processed : 708/963 > 73.52%
# Processed : 709/963 > 73.62%
# Processed : 710/963 > 73.73%
# Processed : 711/963 > 73.83%
# Processed : 712/963 > 73.94%
# Processed : 713/963 > 74.04%
# Processed : 714/963 > 74.14%
# Processed : 715/963 > 74.25%
# Processed : 716/963 > 74.35%
# Processed : 717/963 > 74.45%
# Processed : 718/963 > 74.56%
# Processed : 719/963 > 74.66%
# Processed : 720/963 > 74.77%
# Processed : 721/963 > 74.87%
# Processed : 722/963 > 74.97%
# Processed : 723/963 > 75.08%
# Processed : 724/963 > 75.18%
# Processed : 725/963 > 75.29%
# Processed : 726/963 > 75.39%
# Processed : 727/963 > 75.49%
# Processed : 728/963 > 75.60%
# Processed : 729/963 > 75.70%
# Processed : 730/963 > 75.80%
# Processed : 731/963 > 75.91%
# Processed : 732/963 > 76.01%
# Processed : 733/963 > 76.12%
# Processed : 734/963 > 76.22%
# Processed : 735/963 > 76.32%
# Processed : 736/963 > 76.43%
# Processed : 737/963 > 76.53%
# Processed : 738/963 > 76.64%
# Processed : 739/963 > 76.74%
# Processed : 740/963 > 76.84%
# Processed : 741/963 > 76.95%
# Processed : 742/963 > 77.05%
# Processed : 743/963 > 77.15%
# Processed : 744/963 > 77.26%
# Processed : 745/963 > 77.36%
# Processed : 746/963 > 77.47%
# Processed : 747/963 > 77.57%
# Processed : 748/963 > 77.67%
# Processed : 749/963 > 77.78%
# Processed : 750/963 > 77.88%
# Processed : 751/963 > 77.99%
# Processed : 752/963 > 78.09%
# Processed : 753/963 > 78.19%
# Processed : 754/963 > 78.30%
# Processed : 755/963 > 78.40%
# Processed : 756/963 > 78.50%
# Processed : 757/963 > 78.61%
# Processed : 758/963 > 78.71%
# Processed : 759/963 > 78.82%
# Processed : 760/963 > 78.92%
# Processed : 761/963 > 79.02%
# Processed : 762/963 > 79.13%
# Processed : 763/963 > 79.23%
# Processed : 764/963 > 79.34%
# Processed : 765/963 > 79.44%
# Processed : 766/963 > 79.54%
# Processed : 767/963 > 79.65%
# Processed : 768/963 > 79.75%
# Processed : 769/963 > 79.85%
# Processed : 770/963 > 79.96%
# Processed : 771/963 > 80.06%
# Processed : 772/963 > 80.17%
# Processed : 773/963 > 80.27%
# Processed : 774/963 > 80.37%
# Processed : 775/963 > 80.48%
# Processed : 776/963 > 80.58%
# Processed : 777/963 > 80.69%
# Processed : 778/963 > 80.79%
# Processed : 779/963 > 80.89%
# Processed : 780/963 > 81.00%
# Processed : 781/963 > 81.10%
# Processed : 782/963 > 81.20%
# Processed : 783/963 > 81.31%
# Processed : 784/963 > 81.41%
# Processed : 785/963 > 81.52%
# Processed : 786/963 > 81.62%
# Processed : 787/963 > 81.72%
# Processed : 788/963 > 81.83%
# Processed : 789/963 > 81.93%
# Processed : 790/963 > 82.04%
# Processed : 791/963 > 82.14%
# Processed : 792/963 > 82.24%
# Processed : 793/963 > 82.35%
# Processed : 794/963 > 82.45%
# Processed : 795/963 > 82.55%
# Processed : 796/963 > 82.66%
# Processed : 797/963 > 82.76%
# Processed : 798/963 > 82.87%
# Processed : 799/963 > 82.97%
# Processed : 800/963 > 83.07%
# Processed : 801/963 > 83.18%
# Processed : 802/963 > 83.28%
# Processed : 803/963 > 83.39%
# Processed : 804/963 > 83.49%
# Processed : 805/963 > 83.59%
# Processed : 806/963 > 83.70%
# Processed : 807/963 > 83.80%
# Processed : 808/963 > 83.90%
# Processed : 809/963 > 84.01%
# Processed : 810/963 > 84.11%
# Processed : 811/963 > 84.22%
# Processed : 812/963 > 84.32%
# Processed : 813/963 > 84.42%
# Processed : 814/963 > 84.53%
# Processed : 815/963 > 84.63%
# Processed : 816/963 > 84.74%
# Processed : 817/963 > 84.84%
# Processed : 818/963 > 84.94%
# Processed : 819/963 > 85.05%
# Processed : 820/963 > 85.15%
# Processed : 821/963 > 85.25%
# Processed : 822/963 > 85.36%
# Processed : 823/963 > 85.46%
# Processed : 824/963 > 85.57%
# Processed : 825/963 > 85.67%
# Processed : 826/963 > 85.77%
# Processed : 827/963 > 85.88%
# Processed : 828/963 > 85.98%
# Processed : 829/963 > 86.09%
# Processed : 830/963 > 86.19%
# Processed : 831/963 > 86.29%
# Processed : 832/963 > 86.40%
# Processed : 833/963 > 86.50%
# Processed : 834/963 > 86.60%
# Processed : 835/963 > 86.71%
# Processed : 836/963 > 86.81%
# Processed : 837/963 > 86.92%
# Processed : 838/963 > 87.02%
# Processed : 839/963 > 87.12%
# Processed : 840/963 > 87.23%
# Processed : 841/963 > 87.33%
# Processed : 842/963 > 87.44%
# Processed : 843/963 > 87.54%
# Processed : 844/963 > 87.64%
# Processed : 845/963 > 87.75%
# Processed : 846/963 > 87.85%
# Processed : 847/963 > 87.95%
# Processed : 848/963 > 88.06%
# Processed : 849/963 > 88.16%
# Processed : 850/963 > 88.27%
# Processed : 851/963 > 88.37%
# Processed : 852/963 > 88.47%
# Processed : 853/963 > 88.58%
# Processed : 854/963 > 88.68%
# Processed : 855/963 > 88.79%
# Processed : 856/963 > 88.89%
# Processed : 857/963 > 88.99%
# Processed : 858/963 > 89.10%
# Processed : 859/963 > 89.20%
# Processed : 860/963 > 89.30%
# Processed : 861/963 > 89.41%
# Processed : 862/963 > 89.51%
# Processed : 863/963 > 89.62%
# Processed : 864/963 > 89.72%
# Processed : 865/963 > 89.82%
# Processed : 866/963 > 89.93%
# Processed : 867/963 > 90.03%
# Processed : 868/963 > 90.13%
# Processed : 869/963 > 90.24%
# Processed : 870/963 > 90.34%
# Processed : 871/963 > 90.45%
# Processed : 872/963 > 90.55%
# Processed : 873/963 > 90.65%
# Processed : 874/963 > 90.76%
# Processed : 875/963 > 90.86%
# Processed : 876/963 > 90.97%
# Processed : 877/963 > 91.07%
# Processed : 878/963 > 91.17%
# Processed : 879/963 > 91.28%
# Processed : 880/963 > 91.38%
# Processed : 881/963 > 91.48%
# Processed : 882/963 > 91.59%
# Processed : 883/963 > 91.69%
# Processed : 884/963 > 91.80%
# Processed : 885/963 > 91.90%
# Processed : 886/963 > 92.00%
# Processed : 887/963 > 92.11%
# Processed : 888/963 > 92.21%
# Processed : 889/963 > 92.32%
# Processed : 890/963 > 92.42%
# Processed : 891/963 > 92.52%
# Processed : 892/963 > 92.63%
# Processed : 893/963 > 92.73%
# Processed : 894/963 > 92.83%
# Processed : 895/963 > 92.94%
# Processed : 896/963 > 93.04%
# Processed : 897/963 > 93.15%
# Processed : 898/963 > 93.25%
# Processed : 899/963 > 93.35%
# Processed : 900/963 > 93.46%
# Processed : 901/963 > 93.56%
# Processed : 902/963 > 93.67%
# Processed : 903/963 > 93.77%
# Processed : 904/963 > 93.87%
# Processed : 905/963 > 93.98%
# Processed : 906/963 > 94.08%
# Processed : 907/963 > 94.18%
# Processed : 908/963 > 94.29%
# Processed : 909/963 > 94.39%
# Processed : 910/963 > 94.50%
# Processed : 911/963 > 94.60%
# Processed : 912/963 > 94.70%
# Processed : 913/963 > 94.81%
# Processed : 914/963 > 94.91%
# Processed : 915/963 > 95.02%
# Processed : 916/963 > 95.12%
# Processed : 917/963 > 95.22%
# Processed : 918/963 > 95.33%
# Processed : 919/963 > 95.43%
# Processed : 920/963 > 95.53%
# Processed : 921/963 > 95.64%
# Processed : 922/963 > 95.74%
# Processed : 923/963 > 95.85%
# Processed : 924/963 > 95.95%
# Processed : 925/963 > 96.05%
# Processed : 926/963 > 96.16%
# Processed : 927/963 > 96.26%
# Processed : 928/963 > 96.37%
# Processed : 929/963 > 96.47%
# Processed : 930/963 > 96.57%
# Processed : 931/963 > 96.68%
# Processed : 932/963 > 96.78%
# Processed : 933/963 > 96.88%
# Processed : 934/963 > 96.99%
# Processed : 935/963 > 97.09%
# Processed : 936/963 > 97.20%
# Processed : 937/963 > 97.30%
# Processed : 938/963 > 97.40%
# Processed : 939/963 > 97.51%
# Processed : 940/963 > 97.61%
# Processed : 941/963 > 97.72%
# Processed : 942/963 > 97.82%
# Processed : 943/963 > 97.92%
# Processed : 944/963 > 98.03%
# Processed : 945/963 > 98.13%
# Processed : 946/963 > 98.23%
# Processed : 947/963 > 98.34%
# Processed : 948/963 > 98.44%
# Processed : 949/963 > 98.55%
# Processed : 950/963 > 98.65%
# Processed : 951/963 > 98.75%
# Processed : 952/963 > 98.86%
# Processed : 953/963 > 98.96%
# Processed : 954/963 > 99.07%
# Processed : 955/963 > 99.17%
# Processed : 956/963 > 99.27%
# Processed : 957/963 > 99.38%
# Processed : 958/963 > 99.48%
# Processed : 959/963 > 99.58%
# Processed : 960/963 > 99.69%
# Processed : 961/963 > 99.79%
# Processed : 962/963 > 99.90%
# Exported as .json to winners.json

# %% [markdown]
# ## 4. Check

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#               prize_id  ... acceptance
# 0  4147989774306426835  ...   accepted
# 1  8667244052562133513  ...   accepted
# 2   710472678332515686  ...   accepted
# 3   143844596397185220  ...   accepted
# 4  4835365360172269807  ...   accepted
#
# [5 rows x 12 columns]
